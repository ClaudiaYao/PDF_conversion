# %%
# ensure that the imported .py file will get auto imported and updated whenever there is a change
# %load_ext autoreload
# %autoreload 2

# %%
import os
from ModelSummarizerFix import train_model, load_data
# MODEL_NAME = 'allenai/led-large-16384-arxiv'
# MODEL_NAME = 'allenai/led-base-16384'
# MODEL_NAME = 'facebook/bart-base'
MODEL_NAME = 'facebook/bart-large-cnn'

model, tokenizer = train_model(MODEL_NAME)
# Out:
# Map: 100%|██████████| 517/517 [00:09<00:00, 56.59 examples/s]
# Map: 100%|██████████| 135/135 [00:02<00:00, 50.43 examples/s]

# %%
import os
from ModelSummarizerFix import load_json, test_model
from torch.utils.data import DataLoader

test_file_path =  os.path.join('../dataset/', 'dataset_test_ground_truth.json')   #20 pdfs
test_data = load_json(test_file_path)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)

# Calculate average ROUGE scores across all sections
all_results = []
for item in test_loader:
    section_result = test_model(item, model, tokenizer)
    all_results.append(section_result)
total_sections = len(all_results)
# print("total sections",total_sections)
# total_rouge1 = sum(result.get("ROUGE-1 F1", 0) for result in all_results)
# total_rouge2 = sum(result.get("ROUGE-2 F1", 0) for result in all_results)
# total_rougeL = sum(result.get("ROUGE-L F1", 0) for result in all_results)

# average_rouge1 = total_rouge1 / total_sections
# average_rouge2 = total_rouge2 / total_sections
# average_rougeL = total_rougeL / total_sections

# print("Average ROUGE-1 F1:", average_rouge1)
# print("Average ROUGE-2 F1:", average_rouge2)
# print("Average ROUGE-L F1:", average_rougeL)

# # Save results to JSON file
# with open("summary_results_with_rouge.json", "w") as json_file:
#     json.dump(all_results, json_file, indent=4)
# Out:
# Section Name:  ['Abstract']
# Generated Summary:  ,. and of- theThe in to for on is The a section as with
# Section Name:  ['1. Introduction']
# Generated Summary:  ,. and of- theThe in to for on is The a section as with
# Section Name:  ['2. Topology of the tempered dual']
# Generated Summary:  ,. and of- theThe in to for on is The a section as with
# Section Name:  ['3. Topology of the motion group dual and remarks on the Mackey-Higson bijection']
# Generated Summary:  ,. and of- theThe in to for on is The a section as with
# Section Name:  ['4. Continuity of the Mackey-Higson bijection']
# Generated Summary:  ,. and of- theThe in to for on is The a section as with
# Section Name:  ['Abstract']
# Generated Summary:  ,. and of- theThe in to for on is The a section as with
# Section Name:  ['3. The Thom Isomorphism']
# Generated Summary:  , and.- of theThe in to for on is The a section as with
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 all_results = []
#      11 for item in test_loader:
# ---> 12     section_result = test_model(item, model, tokenizer)
#      13     all_results.append(section_result)
#      14 total_sections = len(all_results)
#
# File d:\git\PDF_conversion\Model Summarizer\ModelSummarizerFix.py:147, in test_model(section, model, tokenizer)
#     145 labels = labels.to(DEVICE)
#     146 with torch.no_grad():
# --> 147 	outputs = model.generate(
#     148 		input_ids=input_ids,
#     149 		# num_beams=5,
#     150 		# no_repeat_ngram_size=2,
#     151 	)
#     153 	# Decode the generated summary using the tokenizer
#     154 	summary_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\generation\utils.py:1655, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1648     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1649         input_ids=input_ids,
#    1650         expand_size=generation_config.num_beams,
#    1651         is_encoder_decoder=self.config.is_encoder_decoder,
#    1652         **model_kwargs,
#    1653     )
#    1654     # 13. run beam search
# -> 1655     result = self._beam_search(
#    1656         input_ids,
#    1657         beam_scorer,
#    1658         logits_processor=prepared_logits_processor,
#    1659         stopping_criteria=prepared_stopping_criteria,
#    1660         pad_token_id=generation_config.pad_token_id,
#    1661         output_scores=generation_config.output_scores,
#    1662         output_logits=generation_config.output_logits,
#    1663         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1664         synced_gpus=synced_gpus,
#    1665         sequential=generation_config.low_memory,
#    1666         **model_kwargs,
#    1667     )
#    1669 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1670     # 11. prepare logits warper
#    1671     logits_warper = self._get_logits_warper(generation_config)
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\generation\utils.py:3171, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, sequential, **model_kwargs)
#    3168     outputs = stack_model_outputs(outputs_per_sub_batch)
#    3170 else:  # Unchanged original behavior
# -> 3171     outputs = self(
#    3172         **model_inputs,
#    3173         return_dict=True,
#    3174         output_attentions=output_attentions,
#    3175         output_hidden_states=output_hidden_states,
#    3176     )
#    3178 if synced_gpus and this_peer_finished:
#    3179     cur_len = cur_len + 1
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\miniconda3\envs\main\Lib\site-packages\accelerate\utils\operations.py:825, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     824 def forward(*args, **kwargs):
# --> 825     return model_forward(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\accelerate\utils\operations.py:813, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     812 def __call__(self, *args, **kwargs):
# --> 813     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\amp\autocast_mode.py:16, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      13 @functools.wraps(func)
#      14 def decorate_autocast(*args, **kwargs):
#      15     with autocast_instance:
# ---> 16         return func(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\models\bart\modeling_bart.py:1728, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1723     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1724         decoder_input_ids = shift_tokens_right(
#    1725             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1726         )
# -> 1728 outputs = self.model(
#    1729     input_ids,
#    1730     attention_mask=attention_mask,
#    1731     decoder_input_ids=decoder_input_ids,
#    1732     encoder_outputs=encoder_outputs,
#    1733     decoder_attention_mask=decoder_attention_mask,
#    1734     head_mask=head_mask,
#    1735     decoder_head_mask=decoder_head_mask,
#    1736     cross_attn_head_mask=cross_attn_head_mask,
#    1737     past_key_values=past_key_values,
#    1738     inputs_embeds=inputs_embeds,
#    1739     decoder_inputs_embeds=decoder_inputs_embeds,
#    1740     use_cache=use_cache,
#    1741     output_attentions=output_attentions,
#    1742     output_hidden_states=output_hidden_states,
#    1743     return_dict=return_dict,
#    1744 )
#    1746 lm_logits = self.lm_head(outputs[0])
#    1747 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\models\bart\modeling_bart.py:1614, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1607     encoder_outputs = BaseModelOutput(
#    1608         last_hidden_state=encoder_outputs[0],
#    1609         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1610         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1611     )
#    1613 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1614 decoder_outputs = self.decoder(
#    1615     input_ids=decoder_input_ids,
#    1616     attention_mask=decoder_attention_mask,
#    1617     encoder_hidden_states=encoder_outputs[0],
#    1618     encoder_attention_mask=attention_mask,
#    1619     head_mask=decoder_head_mask,
#    1620     cross_attn_head_mask=cross_attn_head_mask,
#    1621     past_key_values=past_key_values,
#    1622     inputs_embeds=decoder_inputs_embeds,
#    1623     use_cache=use_cache,
#    1624     output_attentions=output_attentions,
#    1625     output_hidden_states=output_hidden_states,
#    1626     return_dict=return_dict,
#    1627 )
#    1629 if not return_dict:
#    1630     return decoder_outputs + encoder_outputs
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\models\bart\modeling_bart.py:1467, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1454     layer_outputs = self._gradient_checkpointing_func(
#    1455         decoder_layer.__call__,
#    1456         hidden_states,
#    (...)
#    1464         use_cache,
#    1465     )
#    1466 else:
# -> 1467     layer_outputs = decoder_layer(
#    1468         hidden_states,
#    1469         attention_mask=attention_mask,
#    1470         encoder_hidden_states=encoder_hidden_states,
#    1471         encoder_attention_mask=encoder_attention_mask,
#    1472         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1473         cross_attn_layer_head_mask=(
#    1474             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1475         ),
#    1476         past_key_value=past_key_value,
#    1477         output_attentions=output_attentions,
#    1478         use_cache=use_cache,
#    1479     )
#    1480 hidden_states = layer_outputs[0]
#    1482 if use_cache:
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\models\bart\modeling_bart.py:757, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     755 self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
#     756 # add present self-attn cache to positions 1,2 of present_key_value tuple
# --> 757 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     758     hidden_states=hidden_states,
#     759     past_key_value=self_attn_past_key_value,
#     760     attention_mask=attention_mask,
#     761     layer_head_mask=layer_head_mask,
#     762     output_attentions=output_attentions,
#     763 )
#     764 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     765 hidden_states = residual + hidden_states
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\miniconda3\envs\main\Lib\site-packages\transformers\models\bart\modeling_bart.py:545, in BartSdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     542 bsz, tgt_len, _ = hidden_states.size()
#     544 # get query proj
# --> 545 query_states = self.q_proj(hidden_states)
#     546 # get key, value proj
#     547 # `past_key_value[0].shape[2] == key_value_states.shape[1]`
#     548 # is checking that the `sequence_length` of the `past_key_value` is the same as
#     549 # the provided `key_value_states` to support prefix tuning
#     550 if (
#     551     is_cross_attention
#     552     and past_key_value is not None
#     553     and past_key_value[0].shape[2] == key_value_states.shape[1]
#     554 ):
#     555     # reuse k,v, cross_attentions
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File d:\miniconda3\envs\main\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
