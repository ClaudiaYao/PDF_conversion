# %%
import json
from gpt_summary import get_summaries

# %%
article_name = "1901.00009v1"
file = f"processed/{article_name}.json"

# %%
with open(file, encoding='utf-8') as f:
    data = json.load(f)

# %%
get_summaries(data)

# %%
with open(f"gpt_summaries/{article_name}.json", 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
data
# Out:
# [{'Section': 'NA',
# ...
